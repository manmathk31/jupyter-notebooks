# %%
print("computer networks")
# Out:
# computer networks

# %%
# !pip install pandas scikit-learn

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# Load dataset
data = pd.read_csv("network_data.csv")
print("Dataset:")
print(data)

# Features and label
X = data[['packets','bytes','duration']]
y = data['label']

# Split data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# Train model
model = DecisionTreeClassifier()
model.fit(X_train, y_train)

# Prediction
predictions = model.predict(X_test)
print("Predicted Output:", predictions)

# Accuracy
accuracy = accuracy_score(y_test, predictions)
print("Accuracy:", accuracy)

# New traffic test
new_traffic = [[550, 95000, 2]]
result = model.predict(new_traffic)
print("New Traffic Status:", result)
# Out:
# Dataset:
#    packets   bytes  duration       label
# 0      120   20000         5      normal
# 1      130   21000         6      normal
# 2      500   90000         2  suspicious
# 3      110   18000         5      normal
# 4      600  100000         1  suspicious
# 5      140   22000         6      normal
# 6      650  120000         2  suspicious
# 7      125   19500         5      normal
# Predicted Output: ['suspicious' 'normal' 'suspicious']
# Accuracy: 1.0
# New Traffic Status: ['suspicious']
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
# New traffic test
new_traffic = [[550, 95000, 2]]
result = model.predict(new_traffic)
print("New Traffic Status:", result)
# Out:
# New Traffic Status: ['suspicious']
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
